# %% [markdown]
# # Setting up the API

# %%
from dotenv import load_dotenv
import os 
import openai

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # Generating Text

# %%
def generate_text(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=10,
        temperature=0.7
    )
    return response.choices[0].message.content.strip()

# %%
# Example usage
prompt = "Once upon a time"
generated_text = generate_text(prompt)
print(prompt, generated_text)
# Out:
# Once upon a time in a faraway kingdom, there lived a young

# %% [markdown]
# # Customising the output

# %%
def generate_text_custom(prompt, max_tokens=10, temprature=0.7):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=max_tokens,  # changes the number of tokens in the output
        temperature=temprature  # changes the randomness of the output
    )
    return response.choices[0].message.content.strip()

# %%
# Custom usage
prompt = "Once upon a time"
generated_text = generate_text_custom(prompt=prompt, max_tokens=20)
print(prompt, generated_text)
# Out:
# Once upon a time , in a faraway kingdom, there lived a powerful and wise king named King Alexander. He was

# %%
generated_text = generate_text_custom(prompt=prompt, max_tokens=50)
print(prompt, generated_text)
# Out:
# Once upon a time , in a faraway kingdom, there lived a kind and brave princess named Isabella. She was known throughout the land for her compassionate heart and her fierce determination to protect her people.
#
# One day, a powerful dragon began terrorizing the kingdom, burning

# %%
generated_text = generate_text_custom(prompt=prompt, max_tokens=20, temprature=0)
print(prompt, generated_text)
# Out:
# Once upon a time , in a faraway kingdom, there lived a young princess named Aurora. She was known for her

# %%
generated_text = generate_text_custom(prompt=prompt, max_tokens=20, temprature=0)
print(prompt, generated_text)
# Out:
# Once upon a time , in a faraway kingdom, there lived a young princess named Aurora. She was known for her

# %%
generated_text = generate_text_custom(prompt=prompt, max_tokens=20, temprature=1)
print(prompt, generated_text)
# Out:
# Once upon a time in a faraway kingdom, there lived a young princess named Alice. She had long, flowing golden

# %%
generated_text = generate_text_custom(prompt=prompt, max_tokens=20, temprature=1)
print(prompt, generated_text)
# Out:
# Once upon a time in a far-off kingdom, there was a beautiful princess named Isabella. She had long, flowing
